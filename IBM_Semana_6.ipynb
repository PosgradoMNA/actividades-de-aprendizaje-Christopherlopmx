# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Christopherlopmx/blob/main/IBM_Semana_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estadisticas descriptivas
#
# Siempre es bueno primero analizar los datos que estan leyendo (dhaa), pero de forma estandarizada, o sea aplicando métodos estadísticos para hacer ese análisis.

# %% [markdown]
# Por ejemplo puedes usar pandas para tener un resumen de todas las mediciones estadísticas que suelen solicitarse:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ¿Pero que pasas si tienes variables categóricas? Como color, país, nombre, etc. Puees ya ni modo.. jaja, no te creas, lo que haces ahora es agruparlas, es decir acomodarlas según las cuentas y de ahí puedes hacer bins por ejemplo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Otra forma de analizar variables cualitativas son "box plots", donde puedes visualizar la distribución de las variables:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mira en el ejemplo, cuando usas un box plot para comparar variables entre ella:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Y mira esta otra forma de analiza, directamente con regresiones lineales, super simple. Puedes preguntarte cosas como "esta variable y afecta el resultado x?", en el ejemplo es "tamaño de motor influye en el precio?"
#
# ![image.png](data:image/png;base64,...)
#
# y al respuesta es que si influje. La linea azul de la "tendenci" muestra que a mayor tamaño de motor mayor el precio.

# %% [markdown]
# Otra forma de analizar es a través de agrupamiento de datos. Es otra forma de reducir datos y entender los datos a través de todos los datos, puedes agrupar por bloques de alguna variable cualitativa vs una cuantitativa, por ejemplo, precios por color o altura por raza... (de un perrito por ejemplo jaja)

# %% [markdown]
# Se hace un ejemplo de agrupamiento en una tabla:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aquí se esta agrupando precios por body style y luego por drive wheel, y se ve muy interesante cuando se hace una grafica de calor de esta agrupacion:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En la grafica de arriba, esta agrupado por precio a la derecha, y tienes el wheel drive a la izquierda y body type abajo. Se ve que el wheel drive forward fwd y el body type convertible son los más caros.

# %% [markdown]
# El analisis de la varianza es para ver cuál es la relación entre variables categoricas y el resultado que estas buscando.
#
# Una forma de analizar esto es con ANOVA:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Poooor ejemplo. Mira, aquí tenemos dos tipo de coches, los honda y los subarú, comparados por los precios y si te fijas la varianza entre ellos es muy pequeñas, o sea cuestan basicamente lo mismo:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pero, si compras un coche barato y sus variables categóricas vs las del un coche caro, la varianza es muy grande:![image.png](data:image/png;base64,...)

# %% [markdown]
# Esto es medio logico cuando tu sabes por experiencia o porque eres un humano que los jaguar son más caros que los honda, pero la computadora no sabe eso, no ha visto gente manjear coches ni ha llegado a esas conclusiones por experiencia. Mediante este método ella entiende este razonamiento.

# %% [markdown]
# Con anova en python, se ve así:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Entonces, se el test de ANOVA nos da un F-test alto y un p-value bajo, podemos decir que hay una fuerte correlación entre las variables categoricas y otras variables numéricas, en este caso el precio.
#
# Entonces es como decir que, las características cualitativas de un jaguar influyen fuertemente en su precio.

# %% [markdown]
# CORRELACION

# %% [markdown]
# Es basicamente si una variable afecta a otra. Una correlación de 1 es que por cada cambio de 1 unidad en una de las variables, hay un movimiento de 1 unidad en la variable resultante, puede ser +1 0 -1
#
# Se usan regresiones lineales para explicar esto. (ojo correlación no es causalidad:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Una correlación baja es más cerca de 0 y no se ve la tendencia como arriba (correlación negativa, pero correlación non the less), ahí la gráfica no muestra esas tendencias:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# PEARSONS CORRELATION / CORRELACIÓN DE PEARSONS

# %% [markdown]
# Este analisis nos va a dar dos valores:
#
# El coeficiente de la correlación: Que tanto un dato influye en el otro como resultado, un valor de estos en +/-1 significa que un valor influye altamente en el otro, ya sea negativa o positivamente.
#
# P-Value: Que tan seguros estamos del coeficiente de correlación. Mientras más pequeño sea más "seguro" es el valor de la correlación.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En esta gráfica puedes ver varibales y correlaciones a manera de ejemplo:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fijate como cuando es 1 positivo la linea de izquierda a derecha va hacia arriba, cuando es 0, no hay correlación, la linea es horizontal completamente, cuando es 1 negativo, la linea de izquierda a derecha va para abajo.
#
# Python te deja calcularlas con un metodo bien fácil, no tienes que aplicar fórmulas a esto:
#
# ![image.png](data:image/png;base64,...)
#
# y también te deja hacer un plot con la cosa esta para hacer gráficas, esto se hace mediante un mapa de calor que te va mostrando las correlaciones por colores entre dos variables:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mientras más estan en medio, la correlación es más fuerte. Y obviamente puedes ver que las correlaciones exactas a 1 (aunque pueden estar en otros también), siempre son super fuertes a la mitad, porque ahí estan variable vs variable. O sea correlación de precio por ejemplo vs precio.

# %% [markdown]
# LAB

# %%
#importamos estas librerías para empezar el laboratorio de estadisticas descriptivas:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
filename='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

# los datos estan en ese path que llamaremos file name

# %%
# y aquí vuelves un data frame al archivo y ya:

df = pd.read_csv(filename)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
#Paso 1, ver que tipos de valores tienes en tu df


print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
# puedes ir viendo el tipo de dato en cada columna:

df['peak-rpm'].dtypes
# Out:
# dtype('float64')

# %%
#veamos las correlaciones entre los datos
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
#¿qué tal las correlaciones entre unos datos específicos?:

df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %% [markdown]
# Fijate como si esto fuera una tabla (lo de arriba), en la diagonal, es 1, porque es la correlación entre una variable y si mismo y luego tienes las correlaciones entre bore y stroke por ejemplo, es ques  - 0.05, es una correlación negativa bajita. La más alta la veo entre horse power y bore.

# %% [markdown]
# VARIABLES NUMÉRICAS

# %%
#vamos ahora a revisar variables numericas continuas o sea variables de numeros (into o float), como precio y tamaño de motor:
#una forma de analizarlas super visualmente es con una grafica y como ya tenemos mathplot pues ahí va:

sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,) # es para poner esos número socmo título:0.0.53(...)... aunque no se que sifnifica.
# Out:
# (0.0, 53543.377144105245)

# %%
# en fin.. vamos a ver correlaciones:
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
# y tenemos una correlación negativa también en el df
sns.regplot(x="highway-mpg", y="price", data=df)

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
# ¿y cómo se ve una correlación débil? pues así:
sns.regplot(x="peak-rpm", y="price", data=df)

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# VARIABLES CATEGORICAS:

# %%
#¿Qué pasa cuando en nuestros datos tenemos variables como color, o modelo o cosas que no son números?

#podemos usar boxplots para "acomodarlas", en este ejemplo es body stype y el precio, o rangos de precios:

sns.boxplot(x="body-style", y="price", data=df)

# %%
#fijate como tienes rangos por variables categoricas, jumm... parecen velas japonesas, ¿no?

#bueno, mira aquí esta agrupación de uno que solo tiene dos tipos de variables, el acomodo de motor. Y esta bien interesante, porque cuando
#el motor esta atras el precio es más alto y hay menos separación entre los minimos y maximos, pero cuando este adelante, tiende a ser
#más barato y también hay más separaci´n entre el precio mínimo y el máximo:

sns.boxplot(x="engine-location", y="price", data=df)

# %%
#aquí hay otro:
sns.boxplot(x="drive-wheels", y="price", data=df)

# %%
#maaaan imaginate esto por cuentas o por codigo de producto o por codigo postal!!! ¿qué tipo de asesoría podríamos dar con esto?

# %% [markdown]
# ANALISIS DESCRIPTIVO

# %%
# Ahora vamos a describir variables, por las medidas básicas de estadística, como cuentas, medias, medianas, desviaciones, etc.:

df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
#entender que lo de arriba se salta las variables del tipo objeto, entonces para verlas, debes hacerlo igual pero indicando que quieres ver esas
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
#esta es para contar los valores dentro de una columna/variable
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
# y lo puedes volver una df/tabla:
df['drive-wheels'].value_counts().to_frame() #esto .to_frame() lo hace una tabla para analizar.
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
#en el ejercicio se hace lo mismo, pero ahora se renombra la columba drive wheel a value_counts:
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
# y ahora lo vamos a hacer para engine-location as variable
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
#tambien podemos agrupar, por ejemplo, por valores unicos en drive-wheels

df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
#ahora vamos a agruparlos de nuevo pero darle un nombre al df nuevo:

df_group_one = df[['drive-wheels','price']]

#luego de hacer eso, tenemos un grupo que se llama df_group_one y desde ahí podemos calcular promedios y cosas así:

df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean() #el metodo groupby est agrupando por precio promedio en las categorias por drive-wheel
df_group_one
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %%
#¿qué tal si agruparamos por diferencias variables?

df_gptest = df[['drive-wheels','body-style','price']]
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean() #si cambias esta a max o min, te trae la agrupación y el precio max y minimo según el grupo
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
#vamos a pivotear la tabla, para verla de una forma más fácil:

grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
#cuando tienes así los datos ya se pueden analizar muuucho más fácil con gráficas, en este caso tenemos una de calor:

plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
#tienes el precio en la derecha, luego tienes abajo y la izquierda los grupos de body y wheel, pero esta medio confuso porque python
#pone esos números. El código de abajo es para ponerles etiquetas:

fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %% [markdown]
# AHORA SI CORRLEACIÓN Y PVALUES

# %%
df.corr() #con esto podemos ver todas las correlaciones entre las variables:
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
from scipy import stats #importar esto es para hacer los calculos de correlaciones y pvalues

# %%
#aquí vamos a calcular la correlación y el pvalue ahora si:

pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
print("El coeficiente de correlación de pearsons de wheelbase y price es:", pearson_coef, " tenemos un pvalue de:", p_value)
# Out:
# El coeficiente de correlación de pearsons de wheelbase y price es: 0.584641822265508  tenemos un pvalue de: 8.076488270733218e-20

# %% [markdown]
# ANOVA
#
# The Analysis of Variance (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:
#
# F-test score: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.
#
# P-value: P-value tells how statistically significant our calculated score value is.
#
# If our price variable is strongly correlated with the variable we are analyzing, we expect ANOVA to return a sizeable F-test score and a small p-value.

# %%
#basicamente es otro analisis para ver las diferencias entre medias, esto esta interensante para comparar grupos

grouped_test2=df_gptest[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped_test2.head(2)
df_gptest
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
#veamos valores del grupo, para 4wd vs precio

grouped_test2.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
#y podemos ver el analisi de ANOVA

# ANOVA
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'], grouped_test2.get_group('4wd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %%
#Tenemos un valor alto de f y uno casi de 0 en p o sea hay alta significacia estadistica en el grupo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#vamos a ver entre diferentes combinaciones de los miembros del grupo:
#fwd and rwd
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
#4wd and rwd
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('rwd')['price'])  
   
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %%
#4wd and fwd
f_val, p_val = stats.f_oneway(grouped_test2.get_group('4wd')['price'], grouped_test2.get_group('fwd')['price'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666
